# %%
import os
import sys
import torch
import subprocess
from pathlib import Path
from pyrokinetics import Pyro, PyroScan
from pyrokinetics.diagnostics.gs2_gp import gs2_gp
import numpy as np

# %%
REPO_ROOT = Path("/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval")
STEP_DATA_DIR = "/home/Felix/Documents/Physics_Work/Project_Codes/Beta_Prime_Scan/gs2_beta_scan"
STEP_CASE = "n40"

TGLF_BINARY_PATH = os.path.expandvars("/users/hmq514/scratch/TGLF/gacode/tglf/src/tglf")
TGLF_PARSE_SCRIPT = os.path.expandvars("$GACODE_ROOT/tglf/bin/tglf_parse.py")


# load models
models_path = "/home/Felix/Documents/Physics_Work/Project_Codes/8d_3000/"

models = [
            "growth_rate_log", "mode_frequency_log",
        ]

# %%
def Read_from_gs2():
    in_loc = f"{STEP_DATA_DIR}/{STEP_CASE}/gs2.in"
    pyro = Pyro(gk_file=in_loc, gk_code="GS2")

    pyro.numerics.nky = 1
    pyro.numerics.gamma_exb = 0.0
    pyro.local_species.electron.domega_drho = 0.0

    # Use existing parameter with more realistic ky range
    param_1 = "ky" 
    values_1 = np.arange(0.1, 0.2, 0.1)*pyro.numerics.ky.units

    # Add beta parameter with realistic values
    param_2 = "beta"
    values_2 = np.arange(0.01, 0.03, 0.01)*pyro.numerics.beta.units
    
    # Dictionary of param and values
    param_dict = {param_1: values_1 , param_2: values_2}

   

    def enforce_beta_prime(pyro):
        pyro.enforce_consistent_beta_prime()

    # If there are kwargs to function then define here
    param_2_kwargs = {}

    # Switch to TGLF
    pyro.gk_code = "TGLF"

     # Create PyroScan object with more descriptive naming
    pyro_scan_tglf = PyroScan(
        pyro,
        param_dict,
        value_fmt=".4f",  # Increased precision for small beta values
        value_separator="_",
        parameter_separator="_",
        file_name="input.tglf",
    )

    # Add function to enforce consistent beta prime
    pyro_scan_tglf.add_parameter_key(
        parameter_key="beta",
        parameter_attr="numerics", 
        parameter_location=["beta"]
    )

    # Add function to tglf
    pyro_scan_tglf.add_parameter_func(param_2, enforce_beta_prime, param_2_kwargs)

    # Create scan directory and write input files
    try:
        pyro_scan_tglf.write(
            file_name="input.tglf",
            base_directory=REPO_ROOT / "parameter_scan_tglf",
            template_file=None
        )
    except Exception as e:
        print(f"Error writing parameter scan files: {e}")
        return None

    return pyro_scan_tglf

# %%
def run_file_full(sim_dir):
    # Make sure the directory exists
    os.makedirs(sim_dir, exist_ok=True)

    parent = os.path.dirname(sim_dir)
    folder = os.path.basename(sim_dir)

    subprocess.run(
        ["tglf", "-e", folder],
        cwd=parent
    )
    print(f"Running simulation in directory: {sim_dir}")

def run_sim(pyro_scan):
    for run_dir in pyro_scan.run_directories:
        run_file_full(run_dir)

# %%
def load_results(pyro_scan_tglf):
    # Load output from tglf
    pyro_scan_tglf.load_gk_output()

    data_tglf = pyro_scan_tglf.gk_output
    growth_rate_tglf = data_tglf['growth_rate']
    print("tglf data")
    print(f"growth rate: {growth_rate_tglf.ky}")
    print(f"growth rate: {growth_rate_tglf.beta}")
    mode_frequency_tglf = data_tglf['mode_frequency']

    # load GS2_GP results

    data_gs2_gp = gs2_gp(pyro=pyro_scan_tglf, models_path=models_path, models=models)
    growth_rate_gs2_gp,mode_frequency_gs2_gp = data_gs2_gp.scan_ouput(model="growth_rate_log_M12"),data_gs2_gp.scan_ouput(model="mode_frequency_log_M12")
    



    import matplotlib.pyplot as plt
    import matplotlib.gridspec as gridspec

    # Plot growth rate and mode frequency vs ky for different beta values

    
    
    fig = plt.figure(figsize=(9, 3*len(growth_rate_tglf.beta)))
    gs = gridspec.GridSpec(len(growth_rate_tglf.beta), 2, hspace=0, wspace=0.3)

    axes = np.empty((len(growth_rate_tglf.beta), 2), dtype=object)

    for i, beta in enumerate(growth_rate_tglf.beta.values):
        # Create subplots
        ax1 = fig.add_subplot(gs[i, 0])
        ax2 = fig.add_subplot(gs[i, 1])
        axes[i, 0] = ax1
        axes[i, 1] = ax2

        # Plot data
        ax1.plot(growth_rate_tglf.ky, growth_rate_tglf.sel(beta=beta).sel(mode=0), label=rf"tglf_$\beta={beta:.3f}$")
        ax1.plot(growth_rate_gs2_gp.ky, growth_rate_gs2_gp.sel(beta=beta), label=rf"GS2_$\beta={beta:.3f}$")
        ax2.plot(mode_frequency_tglf.ky, mode_frequency_tglf.sel(beta=beta).sel(mode=0), label=rf"tglf_$\beta={beta:.3f}$")
        ax2.plot(mode_frequency_gs2_gp.ky, mode_frequency_gs2_gp.sel(beta=beta), label=rf"GS2_$\beta={beta:.3f}$")

        # Axis labels
        ax1.set_ylabel(r'$\gamma (c_{s}/a)$')
        ax2.set_ylabel(r'$\omega (c_{s}/a)$')

        ax1.grid(True)
        ax2.grid(True)

        # Row label on right-hand side
        ax2.text(
            1.05, 0.5,
            rf"$\beta={beta:.2f}$",
            transform=ax2.transAxes,
            va='center', ha='left',
            fontsize=10
        )
    for i in range(len(growth_rate_tglf.beta) - 1):  # all rows except bottom
        axes[i, 0].set_xticklabels([])
        axes[i, 0].set_xlabel("") 
        axes[i, 1].set_xticklabels([])
        axes[i, 1].set_xlabel("")
    # Only bottom row gets x-axis labels
    axes[-1, 0].set_xlabel(r"$k_y$")
    axes[-1, 1].set_xlabel(r"$k_y$")

    # Layout and title
    fig.tight_layout(rect=[0, 0, 1, 0.96])
    fig.suptitle(r"Plot of Growth rate and Frequency against $k_y$ for different $\beta$ or STEP Case SPR-045",
                fontsize=16, y=0.95)

    # Save everything in ONE file
    plt.savefig(f"Beta_Scans/{STEP_CASE}_all_betas_pairs.png", dpi=300)
    plt.close(fig)




    # Plot growth rate and mode frequency vs beta for different ky values

    fig = plt.figure(figsize=(9, 3*len(growth_rate_tglf.ky)))
    gs = gridspec.GridSpec(len(growth_rate_tglf.ky), 2, hspace=0, wspace=0.3)

    axes = np.empty((len(growth_rate_tglf.ky), 2), dtype=object)

    for i, ky in enumerate(growth_rate_tglf.ky.values):
        # Create subplots run_sim(pyro_scan)
        ax1 = fig.add_subplot(gs[i, 0])
        ax2 = fig.add_subplot(gs[i, 1])
        axes[i, 0] = ax1
        axes[i, 1] = ax2

        # Plot data
        ax1.plot(growth_rate_tglf.beta, growth_rate_tglf.sel(ky=ky).sel(mode=0), label=rf"tglf_$k_y={ky:.2f}$")
        ax1.plot(growth_rate_gs2_gp.beta, growth_rate_gs2_gp.sel(ky=ky), label=rf"gs2_$k_y={ky:.2f}$")
        ax2.plot(mode_frequency_tglf.beta, mode_frequency_tglf.sel(ky=ky).sel(mode=0), label=rf"tglf_$k_y={ky:.2f}$")
        ax2.plot(mode_frequency_gs2_gp.beta, mode_frequency_gs2_gp.sel(ky=ky), label=rf"gs2_$k_y={ky:.2f}$")

        # Axis labels
        ax1.set_ylabel(r'$\gamma (c_{s}/a)$')
        ax2.set_ylabel(r'$\omega (c_{s}/a)$')

        ax1.grid(True)
        ax2.grid(True)

        # Row label on right-hand side
        ax2.text(
            1.05, 0.5,
            rf"$k_y={ky:.2f}$",
            transform=ax2.transAxes,
            va='center', ha='left',
            fontsize=10
        )
    for i in range(len(growth_rate_tglf.ky) - 1):  # all rows except bottom
        axes[i, 0].set_xticklabels([])
        axes[i, 0].set_xlabel("") 
        axes[i, 1].set_xticklabels([])
        axes[i, 1].set_xlabel("")
    # Only bottom row gets x-axis labels
    axes[-1, 0].set_xlabel(r"$\beta$")
    axes[-1, 1].set_xlabel(r"$\beta$")

    # Layout and title
    fig.tight_layout(rect=[0, 0, 1, 0.96])
    fig.suptitle(r"Plot of Growth rate and Frequency against $\beta$ for different $k_y$ for STEP Case SPR-045",
                fontsize=16, y=0.95)

    # Save everything in ONE file
    plt.savefig(f"Beta_Scans/{STEP_CASE}_all_ky_pairs.png", dpi=300)
    plt.close(fig)

# %%
pyro_scan_tglf = Read_from_gs2()
print(pyro_scan_tglf.run_directories)
#run_sim(pyro_scan_tglf)
load_results(pyro_scan_tglf)
# Out:
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyro.py:1651: UserWarning: Explicitly set value of beta (0.09092868468130633 beta_ref_ee_B0) is inconsistent with value from physical reference values (0.09609377154804474 beta_ref_ee_B0)
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/numerics.py:135: UserWarning: missing unit from 0.0 vref_most_probable / lref_minor_radius, adding vref_most_probable / lref_minor_radius. To suppress this warning, specify units. Will maintain units if not specified from now on
#   warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/local_species.py:576: UserWarning: missing unit from domega_drho, adding vref_nrl / lref_minor_radius ** 2. To suppress this warning, specify units. Will maintain units if not specified from now on
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyro.py:345: UserWarning: Setting gk_code to TGLF without first reading a gyrokinetics file of that type. Creating a new context using the default template file for TGLF and data from the previous context (if available).
#   warnings.warn(warn_msg, UserWarning)
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyroscan.py:245: UserWarning: Adding units [1 / rhoref_gs2] to ky as it has not been specified. To suppress this warning please add units
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyroscan.py:245: UserWarning: Adding units [beta_ref_ee_B0] to beta as it has not been specified. To suppress this warning please add units
#   warnings.warn(
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/.venv/lib/python3.13/site-packages/xarray/backends/api.py:651: RuntimeWarning: 'netcdf4' fails while guessing
#   engine = plugins.guess_engine(filename_or_obj)
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/.venv/lib/python3.13/site-packages/xarray/backends/api.py:651: RuntimeWarning: 'scipy' fails while guessing
#   engine = plugins.guess_engine(filename_or_obj)
# /home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/.venv/lib/python3.13/site-packages/xarray/backends/api.py:651: RuntimeWarning: 'h5netcdf' fails while guessing
#   engine = plugins.guess_engine(filename_or_obj)
# [PosixPath('/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100'), PosixPath('/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0200')]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/factory.py:37, in Factory.type(self, key)
#      36 try:
# ---> 37     return self._registered_types[key]
#      38 except KeyError as exc:
#
# KeyError: '/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:136, in _chain_exceptions(exc, *excs)
#     135 try:
# --> 136     _chain_exceptions(*excs)
#     137 except Exception as chain:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:140, in _chain_exceptions(exc, *excs)
#     139 else:
# --> 140     raise exc
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:160, in FileReaderFactory.type(self, key)
#     159 try:
# --> 160     return super().type(key)
#     161 except KeyError as key_error:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/factory.py:39, in Factory.type(self, key)
#      38 except KeyError as exc:
# ---> 39     raise KeyError(
#      40         f"'{key}' is not recognised as a type of {self._super_class.__name__}"
#      41     ) from exc
#
# KeyError: "'/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100' is not recognised as a type of FileReader"
#
# The above exception was the direct cause of the following exception:
#
# FileInferenceException                    Traceback (most recent call last)
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:136, in _chain_exceptions(exc, *excs)
#     135 try:
# --> 136     _chain_exceptions(*excs)
#     137 except Exception as chain:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:138, in _chain_exceptions(exc, *excs)
#     137     except Exception as chain:
# --> 138         raise exc from chain
#     139 else:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:163, in FileReaderFactory.type(self, key)
#     162 try:
# --> 163     return super().type(self._infer_file_type(key))
#     164 except (FileNotFoundError, FileInferenceException) as infer_error:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:191, in FileReaderFactory._infer_file_type(self, filename)
#     190         excs[key] = exc
# --> 191 raise FileInferenceException(excs)
#
# FileInferenceException: Could not infer file type. The following exceptions were raised:
# + 'CGYRO' raised --> RuntimeError("Missing the file '/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100/input.cgyro'")
# + 'GENE' raised --> RuntimeError("GKOutputReaderGENE: Could not find GENE output files in the directory '/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100'.")
# + 'GKW' raised --> RuntimeError("Missing the file '/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100/input.dat'")
# + 'GS2' raised --> RuntimeError('Error occurred reading GS2 output file')
# + 'GX' raised --> RuntimeError('Error occurred reading GX output file')
# + 'STELLA' raised --> ValueError("did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'scipy']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:\nhttps://docs.xarray.dev/en/stable/getting-started-guide/installing.html\nhttps://docs.xarray.dev/en/stable/user-guide/io.html")
# + 'TGLF' raised --> RuntimeError("Couldn't find TGLF file '/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100/out.tglf.run'")
# + 'IDS' raised --> RuntimeError()
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyroscan.py:368, in PyroScan.load_gk_output(self, output_convention, tolerance_time_range)
#     366 try:
# --> 368     pyro.load_gk_output(output_convention=output_convention)
#     370     if "mode" in pyro.gk_output.dims:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyro.py:1238, in Pyro.load_gk_output(self, path, local_norm, output_convention, load_fields, load_fluxes, load_moments, drop_nan, **kwargs)
#    1237 self.gk_output_file = path
# -> 1238 self.gk_output = read_gk_output(
#    1239     path,
#    1240     norm=local_norm,
#    1241     output_convention=output_convention,
#    1242     load_fields=load_fields,
#    1243     load_fluxes=load_fluxes,
#    1244     load_moments=load_moments,
#    1245     **kwargs,
#    1246 )
#    1248 if drop_nan:
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/gk_code/gk_output.py:994, in read_gk_output(path, norm, output_convention, load_fields, load_fluxes, load_moments, gk_type, **kwargs)
#     963 r"""
#     964 Read gyrokinetics output file(s) from disk, returning an `GKOutput` instance.
#     965
#    (...)    992     If path doesn't exist or isn't a file.
#     993 """
# --> 994 return GKOutput.from_file(
#     995     path,
#     996     file_type=gk_type,
#     997     norm=norm,
#     998     output_convention=output_convention,
#     999     load_fields=load_fields,
#    1000     load_fluxes=load_fluxes,
#    1001     load_moments=load_moments,
#    1002     **kwargs,
#    1003 )
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:245, in ReadableFromFile.from_file(cls, path, file_type, **kwargs)
#     244 # Infer reader type from path if not provided with file_type
# --> 245 reader = cls._factory(str(path) if file_type is None else file_type)
#     246 return reader(path, **kwargs)
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/factory.py:66, in Factory.__call__(self, key, *args, **kwargs)
#      65 """Alternative to `create`"""
# ---> 66 return self.create(key, *args, **kwargs)
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/factory.py:45, in Factory.create(self, key, *args, **kwargs)
#      44 """Create a new object of type ``key``, forwarding all arguments."""
# ---> 45 return self.type(key)(*args, **kwargs)
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:174, in FileReaderFactory.type(self, key)
#     166 msg = dedent(
#     167     f"""\
#     168     Unable to determine the type of '{c}' from the input '{key}'. If
#    (...)    172     """
#     173 ).replace("\n", " ")
# --> 174 _chain_exceptions(RuntimeError(msg), infer_error, key_error)
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/file_utils.py:138, in _chain_exceptions(exc, *excs)
#     137     except Exception as chain:
# --> 138         raise exc from chain
#     139 else:
#
# RuntimeError: Unable to determine the type of 'GKOutput' from the input '/home/Felix/Documents/Physics_Work/Project_Codes/GP_Model_Eval/parameter_scan_tglf/ky_0.1000_beta_0.0100'. If you supplied a file name, please check the exceptions raised above from each GKOutput reader, and try fixing any reported issues. It may also help to specify the file type explicitly.
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[14], line 4
#       2 print(pyro_scan_tglf.run_directories)
#       3 #run_sim(pyro_scan_tglf)
# ----> 4 load_results(pyro_scan_tglf)
#
# Cell In[11], line 3, in load_results(pyro_scan_tglf)
#       1 def load_results(pyro_scan_tglf):
#       2     # Load output from tglf
# ----> 3     pyro_scan_tglf.load_gk_output()
#       5     data_tglf = pyro_scan_tglf.gk_output
#       6     growth_rate_tglf = data_tglf['growth_rate']
#
# File ~/Documents/Physics_Work/Project_Codes/GP_Model_Eval/pyrokinetics/src/pyrokinetics/pyroscan.py:447, in PyroScan.load_gk_output(self, output_convention, tolerance_time_range)
#     444     pyro.gk_output = None
#     446 except (FileNotFoundError, OSError, IndexError, RuntimeError, KeyError):
# --> 447     growth_rate.append(growth_rate[0] * np.nan)
#     448     mode_frequency.append(mode_frequency[0] * np.nan)
#     449     growth_rate_tolerance.append(growth_rate_tolerance[0] * np.nan)
#
# IndexError: list index out of range
